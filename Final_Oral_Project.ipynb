# %% [markdown]
# <a href="https://colab.research.google.com/github/huojiajin/deep-activity-rec/blob/master/Final_Oral_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1、Dataset**

# %% [markdown]
# We choosed a dataset which is related with volleyball. More exactly, they are the frames of the videos of the volleyball matches. So that we can detect the players' action in the matches, such as standing, moving, spiking and so on.

# %% [markdown]
# ![dataset2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The dataset has the following features:
# *   4830 frames from 55 videos
# *   each visible player has be annotaed

# %% [markdown]
# # **2、Training**

# %% [markdown]
# We uploaded the part of dataset into the EasyDL, which is a AutoML platform of Baidu, and converted the format of the config files. Finally, we have uploaded 2278 images with 8 labels name into the platform.

# %% [markdown]
# ![upload.png](data:image/png;base64,...)

# %% [markdown]
# And then, I created a model and trained it automatically by the platform.

# %% [markdown]
# ![training.png](data:image/png;base64,...)

# %% [markdown]
# # 3、Testing

# %% [markdown]
# After the platform remined us that the model has trained, we tested the model and maked sure it's work.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4、Deploying

# %% [markdown]
# We downloaded the Android Studio and deployed the model in the android phone successfully. We can see the details in the following video.
#
# [The video](https://youtu.be/Fasvfi6HrTY)
